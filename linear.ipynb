# %%
import torch
import torch.nn as nn 
import torch.optim as op 
import matplotlib.pyplot as plt

# %%
from utils.tranning_algo import learningData
from utils.Learning_Test import test_by_user_data

model=learningData()
X=torch.tensor([[200.0, 30.0, 50.0, 60.0]])
predict=test_by_user_data(model,X)
print("Prediction:", predict)
# Out:
# Epoch [100/1000], Loss: 98.1494
# Epoch [200/1000], Loss: 11.0685
# Epoch [300/1000], Loss: 7.3180
# Epoch [400/1000], Loss: 5.3391
# Epoch [500/1000], Loss: 3.9060
# Epoch [600/1000], Loss: 2.8613
# Epoch [700/1000], Loss: 2.0995
# Epoch [800/1000], Loss: 1.5441
# Epoch [900/1000], Loss: 1.1391
# Epoch [1000/1000], Loss: 0.8437
# Prediction: tensor([[1212.2700]])
