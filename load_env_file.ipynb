# %%
from dotenv import load_dotenv
import os
import sys
import json
from dotenv import load_dotenv

# %%
load_dotenv('D:\\python\\keyEnv.txt')
sys.path.append('../')

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from utils.create_llm import create_google_llm
load_dotenv("D:/python/keyEnv.env")
#print(os.getenv("GEMINI_API_KEY"))
# SECRETE_KEY =os.getenv("GEMINI_API_KEY")
# llm = ChatGoogleGenerativeAI(
#     model="gemini-3-flash-preview",
#     api_key=SECRETE_KEY,   # directly paste key
#     temperature=0
# )
llm= create_google_llm()
# Use invoke instead of generate
response = llm.invoke('''from langchain_google_genai import ChatGoogleGenerativeAI
load_dotenv("D:/python/keyEnv.env")
#print(os.getenv("GEMINI_API_KEY"))
SECRETE_KEY =os.getenv("GEMINI_API_KEY")
llm = ChatGoogleGenerativeAI(
    model="gemini-3-flash-preview", 
    api_key=SECRETE_KEY,   # directly paste key
    temperature=0
) explain this code?''')
print(response.text)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# This code initializes a connection to Google's **Gemini AI** using the **LangChain** framework. It is designed to set up a Large Language Model (LLM) instance that you can use to build AI-powered applications.
#
# Here is a step-by-step breakdown:
#
# ### 1. Importing the Library
# ```python
# from langchain_google_genai import ChatGoogleGenerativeAI
# ```
# *   This imports the specific class (`ChatGoogleGenerativeAI`) required to interact with Google’s Gemini models through LangChain. LangChain is a popular framework that makes it easier to build LLM applications.
#
# ### 2. Loading the API Key
# ```python
# load_dotenv("D:/python/keyEnv.env")
# SECRETE_KEY = os.getenv("GEMINI_API_KEY")
# ```
# ...

# %%
# %pip install -U langchain-google-genai

# %%
pip uninstall langchain-google-genai -y
pip install --upgrade google-generativeai
pip install --upgrade langchain-google-genai
